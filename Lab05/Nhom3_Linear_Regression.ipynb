# %% [markdown]
# # NT532 - CÔNG NGHỆ INTERNET OF THINGS HIỆN ĐẠI
#
# **Hướng dẫn**:
# *   Khởi động runtime: chọn **Connect** tại góc trên bên phải.
# *   Hoàn thành tất cả các mục có comment `YOUR CODE HERE` và các câu hỏi được thể hiện.
# *   Chạy toàn bộ các block code để kiểm tra: Ở thanh menu, chọn Runtime$\rightarrow$Run all.

# %% [markdown]
# ---

# %% [markdown]
# # PHẦN 1: CÀI ĐẶT MÔ HÌNH LINEAR REGRESSION VỚI KERAS

# %% [markdown]
# ## 1. Import các thư viện Keras
#
# Đầu tiên, chúng ta sẽ import các thư viện, module, hàm của `Keras`:
# - `Input`: để nhận dữ liệu đầu vào cho mô hình.
# - `Dense`: hay còn gọi là lớp Fully Connected (Lớp kết nối đầy đủ), một thành phần quan trọng của các mô hình dựa trên mạng Neural Network.
# - `Model`: đây là lớp đối tượng mô hình được sử dụng để đóng gói lớp đầu vào, đầu ra, sau đó huấn luyện với phương thức `fit` và dự đoán kết quả với `predict`.
# - `load_model`: hàm sử dụng để load mô hình lên từ file.

# %%
from keras.layers import Input, Dense
from keras import Model
import tensorflow as tf
from keras.models import load_model

# %% [markdown]
# ## 2. Tạo dữ liệu mẫu (toy example)
# Tiếp theo, ta sẽ tiến hành tạo dữ liệu mẫu để huấn luyện và kiểm thử.
#
# Dữ liệu được tạo ra là các điểm xoay xung quanh một đường thẳng cho trước với một số nhiễu được thêm vào trên từng điểm dữ liệu.
#
# Đường thẳng được khởi tạo theo qui tắc:
# `y = [(STT nhóm - 5 + 3 - 2) + STT nhóm % (2 + 1)] * x + STT nhóm * random(0,3)`

# %%
import numpy as np

import matplotlib.pyplot as plt
rng = np.random.RandomState(1)
# Khởi tạo đường thẳng theo qui tắc ở trên
# x được cho trước và y được tạo từ đường thẳng trên và cộng thêm nhiễu dược khởi tạo ngẫu nhiên
# y= -x+3.random(0.3)
# YOUR CODE HERE
rng = np.random.RandomState(1)  # Khởi tạo hạt giống cho số ngẫu nhiên
x_train = 10 * rng.rand(100) # Tạo mảng x với 50 điểm ngẫu nhiên trong khoảng từ 0 đến 10
random_numb = rng.uniform(0, 3, size=100)  # Tạo mảng random_numb với 50 số ngẫu nhiên từ 0 đến 3
#tính y
print(random_numb)
y_train = -1*x_train+3*random_numb
# raise NotImplementedError()

# Trực quan hóa dữ liệu bằng các hình tròn màu đỏ
plt.plot(x_train, y_train, 'ro')
plt.show()
# Out:
# [0.97993471 1.58117431 2.6578263  1.07180928 2.72560545 1.87008035
#  0.04746373 2.7883117  2.07269075 2.99196855 0.51702153 0.41140725
#  2.79778639 2.09045448 0.19800052 2.26638916 2.26162857 2.76907361
#  2.13457428 0.37281289 0.0596404  0.07863296 0.08491946 0.7386332
#  2.58008385 1.61649319 1.65846594 2.52609268 0.37251995 0.83755104
#  1.75727781 2.90878724 1.68309066 0.05594187 2.40189802 0.69892282
#  2.42131559 1.16358193 2.59062556 2.24136493 1.6687207  0.40936568
#  0.17975307 0.36403037 0.13365564 0.32248239 0.67712802 2.13896694
#  1.67915095 0.03766794 0.21592284 2.90182899 1.70430139 0.6098797
#  0.75697723 2.23147756 0.58628844 1.74407678 2.91005997 2.5404864
#  0.71954328 1.48130914 1.85986716 2.4869427  0.47037418 0.05572861
#  0.21006643 1.45903533 1.81898838 1.70655431 0.95208723 2.96584846
#  1.73923566 1.14042352 1.65284466 2.23600329 2.00769868 0.79475867
#  0.1990045  1.11025259 1.88915252 0.63052203 2.25826666 0.19960944
#  0.7809453  2.41426369 0.58030285 1.91838264 1.57401093 2.77442391
#  0.78989031 0.19788327 2.20519789 2.31653409 2.72344756 2.79591621
#  0.04185472 0.70308626 1.85033507 2.84704896]

# %% [markdown]
# *italicized text*## 3. Cài đặt mô hình Linear Regression
# Tiếp đến, chúng ta sẽ tiến hành định nghĩa mô hình Linear Regression dựa trên các đối tượng được cung cấp bởi Keras. Các nội dung này sinh viên cần tìm hiểu ý nghĩa, cách thức sử dụng để hiểu được nội dung được định nghĩa.
#
# <p align="center">
#   <img src="https://static.wixstatic.com/media/a27d24_c73a810c7b9e43c9b339ca529d9c9122~mv2.png" />
# </p>

# %%
#  - Tạo biến `input` với lớp đối tượng `Input` của Keras, truyền vào kích thước đầu vào `input_dim`
#  - Tạo biến `output` với lớp đối tượng `Dense` của Keras, truyền vào các tham số: kích thước output, có sử dụng bias, không sử dụng hàm activation
#  - Cuối cùng, khởi tạo mô hình với `Model` của Keras, truyền vào `input` và `output` để tạo thành mô hình

# input_dim được gọi là số chiều của vector đầu vào. Vậy theo bạn, input_dim của bài toán Linear Regression bằng bao nhiêu? Giải thích.
# YOUR CODE HERE
input_dim = [1,]

input = Input(shape = input_dim)
output = Dense(1, use_bias=True, activation=None)(input)
LinearRegression = Model(input, output)

# Để hiển thị kiến trúc của mô hình ta gọi phương thức `summary`
print("The architecture of Linear Regression model: ")
LinearRegression.summary()
# Out:
# The architecture of Linear Regression model:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1)]               0
#
#  dense_6 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.1) # Stochastic Gradient Descent

# Tìm hiểu về loss function. Loss function được sử dụng trong Linear Regression là gì?
# YOUR CODE HERE
loss = 'mae'

LinearRegression.compile(optimizer=opt, loss=loss)

# Thông số epochs là gì?

hist = LinearRegression.fit(x_train, y_train, epochs=35)
# Out:
# Epoch 1/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7378
# Epoch 2/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7782
# Epoch 3/35
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7145
# Epoch 4/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.9094
# Epoch 5/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6974
# Epoch 6/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6580
# Epoch 7/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6467
# Epoch 8/35
# 4/4 [==============================] - 0s 3ms/step - loss: 3.0519
# Epoch 9/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6921
# Epoch 10/35
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7410
# Epoch 11/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7039
# Epoch 12/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8357
# Epoch 13/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6331
# Epoch 14/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8060
# Epoch 15/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8118
# Epoch 16/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6609
# Epoch 17/35
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6917
# Epoch 18/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7125
# Epoch 19/35
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6557
# Epoch 20/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7911
# Epoch 21/35
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7574
# Epoch 22/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6301
# Epoch 23/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6980
# Epoch 24/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7135
# Epoch 25/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8693
# Epoch 26/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6133
# Epoch 27/35
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6159
# Epoch 28/35
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6961
# Epoch 29/35
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7160
# Epoch 30/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6338
# Epoch 31/35
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6154
# Epoch 32/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6651
# Epoch 33/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6149
# Epoch 34/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7312
# Epoch 35/35
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7948

# %%
# Hiển thị loss theo số epoch
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 4. Lưu trữ và tái sử dụng model
# Sau khi đã huấn luyện, ta lưu mô hình để có thể tái sử dụng trong tương lai.
#
# Sử dụng phương phương thức `save` để lưu trữ mô hình và `load_model` để tải lại mô hình và tái sử dụng.
#
# Điều này có thể áp dụng để sử dụng mô hình trong tương lai mà **KHÔNG CẦN PHẢI HUẤN LUYỆN LẠI**.

# %%
LinearRegression.save('linear_regression_model.h5')

pretrain_LinearRegression = load_model('linear_regression_model.h5')

# %% [markdown]
# ## 5. Trực quan hóa mô hình và dự đoán với dữ liệu test

# %%
result = pretrain_LinearRegression.get_weights()
print('Tham số tối ưu: ')

# `theta` được gọi là gọi là hệ số học tập được thông qua quá trình huấn luyện
# bias được gọi là hệ số tự do
# Từ thông số `result` thu được, tìm theta và bias thu được

# YOUR CODE HERE
theta = result[0]
bias = result[1]

print('Trong đó: ')
print('   - bias (hệ số tự do) : ', bias)
print('   - theta (hệ số cho dữ liệu đầu vào): ', theta)
# Out:
# Tham số tối ưu:
# Trong đó:
#    - bias (hệ số tự do) :  [3.7562497]
#    - theta (hệ số cho dữ liệu đầu vào):  [[-0.8229634]]

# %%
# Trực quan hóa dữ liệu và mô hình sau khi huấn luyện


# Trực quan hóa mô hình
# Tìm cách vẽ dường thẳng thu được từ dữ liệu gốc và các hệ số thu thập được ở trên để thể hiện lên biểu đồ
# YOUR CODE HERE
y_line = LinearRegression.predict(x_train)
plt.plot(x_train,y_line,'b-')
plt.plot(x_train, y_train, 'ro')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend(['Dữ liệu', 'Mô hình'])
# plt.title('Biểu đồ dữ liệu và mô hình')
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# Nhận xét về tham số tối ưu và đường thẳng `y` được khởi tạo ở đầu bước 2 dùng để khởi tạo các điểm dữ liệu.

# %% [markdown]
# Nhận xét của bạn?

# %% [markdown]
# Cuối cùng, chúng ta sẽ thử nghiệm với dữ liệu kiểm tra x_test.
# Từ đường thẳng `y` được khởi tạo.

# %%
x_test = [-5, 0, 5]
y_pred = pretrain_LinearRegression.predict(x_test)

print("Các giá trị mà mô hình hồi quy dự đoán trên x_test: ", x_test)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# Các giá trị mà mô hình hồi quy dự đoán trên x_test:  [-5, 0, 5]
# [[ 8.657015 ]
#  [ 3.6124997]
#  [-1.4320159]]

# %% [markdown]
# Từ các nhận xét của bạn ở trên, hãy tiến hành nhận xét về kết quả thu được
#
# *   List item
# *   List item
#
# `y_pred` so với các giá trị sẽ đạt được khi sử dụng đường thẳng gốc `y`.

# %%
options = ['Hả? Gì? Không biết nữa :( Không có biết :((((', 'Giá trị từ y và giá trị được dự đoán từ các tham số tối ưu là gần giống nhau', 'Giá trị từ y và giá trị được dự đoán từ các tham số tối ưu là một', 'Giá trị từ y và giá trị được dự đoán từ các tham số tối ưu là khác nhau']

# Hãy chọn your_choice bằng 0, 1, 2, 3 tương ứng với các lựa chọn ở trên
your_choice = 1


print("Kết quả không thể nào khác, đó chính là: ", options[your_choice])
# Out:
# Kết quả không thể nào khác, đó chính là:  Giá trị từ y và giá trị được dự đoán từ các tham số tối ưu là gần giống nhau

# %% [markdown]
# # PHẦN 2: SỬ DỤNG LINEAR REGRESSION VỚI BÀI TOÁN CỤ THỂ
#
# Tại phần thực hành này, sinh viên sẽ tìm hiểu cách sử dụng dataset được cung cấp tại https://www.kaggle.com/datasets/budincsevity/szeged-weather
#
# Đồng thời, chúng ta sẽ tìm hiểu về quy trình cơ bản khi bước đầu tiếp cận với Machine Learning.
# <p align="center">
#   <img src="https://912556475-files.gitbook.io/~/files/v0/b/gitbook-legacy-files/o/assets%2F-LxEH5JsS0dPf0_ZuSqD%2F-M1wiuy398NBw5hRkvvv%2F-M1wj99fwHoLQ4kNR5jW%2FSlide2.PNG?alt=media&token=ac4952bb-595b-4acf-8280-6814076c50bd" />
# </p>

# %% [markdown]
# ## 1. Chuẩn bị dữ liệu
# Đầu tiên, chúng ta sẽ tiến hành download dữ liệu được cung cấp tại: https://www.kaggle.com/datasets/budincsevity/szeged-weather
#
# Tiến hành copy dataset đã download ở trên vào drive của bạn, mount drive với google colab và lập trình để đọc file csv ở trên.
#
# Cuối cùng, thực hiện phân tích, tiền xử lý dữ liệu, làm tiền đề để thực hiện huấn luyện mô hình.

# %%
# Mount dữ liệu từ drive của bạn và google colab
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd

# Tiến hành đọc csv dataset bằng phương thức `read_csv` từ thư viện pandas

# YOUR CODE HERE
url_to_csv = '/content/weatherHistory.csv'


data = pd.read_csv(url_to_csv)
data = pd.DataFrame(data)

# %%
# Sử dụng `head` để kiểm tra tổng quát dataset
data.head(10)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
# 6  2006-04-01 06:00:00.000 +0200  Partly Cloudy        rain         7.733333
# 7  2006-04-01 07:00:00.000 +0200  Partly Cloudy        rain         8.772222
# 8  2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain        10.822222
# 9  2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain        13.772222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
# 6                  5.522222      0.95            12.3648
# 7                  6.527778      0.89            14.1519
# 8                 10.822222      0.82            11.3183
# 9                 13.772222      0.72            12.5258
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
# 5                   258.0          14.9569         0.0               1016.66
# 6                   259.0           9.9820         0.0               1016.72
# 7                   260.0           9.9820         0.0               1016.84
# 8                   259.0           9.9820         0.0               1017.37
# 9                   279.0           9.9820         0.0               1017.22
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.
# 5  Partly cloudy throughout the day.
# 6  Partly cloudy throughout the day.
# 7  Partly cloudy throughout the day.
# 8  Partly cloudy throughout the day.
# 9  Partly cloudy throughout the day.

# %%
# Sử dụng `describe` để tổng hợp các thông số, góp phần phân tích dữ liệu rõ ràng hơn
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     24508.000000              24508.000000  24508.000000
# mean         11.770534                 10.660277      0.718518
# std           9.563249                 10.654191      0.191128
# min         -14.088889                -22.094444      0.000000
# 25%           4.444444                  2.050000      0.590000
# 50%          11.288889                 11.288889      0.760000
# 75%          18.794444                 18.794444      0.870000
# max          39.905556                 38.377778      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       24508.000000            24508.000000     24507.000000     24507.0
# mean           10.796392              192.762078        10.163295         0.0
# std             6.881443              105.390871         3.749648         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.812100              124.000000         9.804900         0.0
# 50%             9.861250              191.000000         9.982000         0.0
# 75%            14.135800              290.000000        11.398800         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          24507.000000
# mean            1000.917116
# std              129.525999
# min                0.000000
# 25%             1011.975000
# 50%             1016.750000
# 75%             1022.340000
# max             1046.380000

# %%
# `shape` dùng để thể hiện số chiều của array
print(type(data))
data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (24508, 12)

# %%
# Thể hiện các label của dữ liệu
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
# Thể hiện số điểm dữ liệu NaN -> xử lý missing values
data.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             1
# Loud Cover                  1
# Pressure (millibars)        1
# Daily Summary               1
# dtype: int64

# %%
# Cách 1: Bỏ các hàng missing values
# Lưu trữ lại và kiểm tra cách xử lý
drop_nan_data = data.copy()
drop_nan_data.dropna(inplace=True)  
drop_nan_data.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
# Copy dữ liệu từ dataset gốc, tiến hành tạo trường hợp để xử lý missing values
replace_nan_data = data.iloc[95514:95519].copy()

# Kiểm tra dữ liệu copy được
print(replace_nan_data)

# Ta có thể quan sát được trường thông tin `Precip Type` có 2 giá trị NaN
# Thực hiện tạo dữ liệu giả `Humidity` trên 2 điểm dữ liệu này
replace_nan_data.loc[pd.isnull(replace_nan_data['Precip Type']), 'Humidity'] = np.nan

# Kiểm tra lại
print(replace_nan_data)
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
# Cách 2: Thay thế các hàng missing values bằng một giá trị xác định 
replace_nan_data['Precip Type'].fillna(value = 'rain', inplace=True)  

# Kiểm tra lại kết quả
print(replace_nan_data['Humidity'])

# Cách 3: Điền các missing values với giá trị `mean`
replace_nan_data['Humidity'].fillna(value = replace_nan_data['Humidity'].mean() , inplace=True)

# Kiểm tra lại
print(replace_nan_data['Humidity'])
# Out:
# Series([], Name: Humidity, dtype: float64)
# Series([], Name: Humidity, dtype: float64)

# %%
# Tiếp theo, chúng ta sẽ tiến hành tạo dữ liệu ảo để tập làm quen với việc xử lý missing values đổi với trường `Temperature (C)`
data.loc[pd.isnull(data['Precip Type']), 'Temperature (C)'] = np.nan

# Cách 4: Tìm hiểu về `interpolate()` và thực hiện nội suy các giá trị NaN ở trên
# YOUR CODE HERE
data.interpolate(method='linear', axis=0, limit=None, inplace=False, limit_direction='forward', limit_area=None, downcast=None)
data.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             1
# Loud Cover                  1
# Pressure (millibars)        1
# Daily Summary               1
# dtype: int64

# %%
# Ta chọn 2 trường dữ liệu là `Humidity` và `Temperature (C)` để tiến hành phân tích và thực hiện
data_selected = data[['Humidity', 'Temperature (C)']]

# %%
data_selected.head()
# Out:
#    Humidity  Temperature (C)
# 0      0.89         9.472222
# 1      0.86         9.355556
# 2      0.89         9.377778
# 3      0.83         8.288889
# 4      0.83         8.755556

# %%
# Trực quan hoá dữ liệu bằng biểu đồ
plt.figure(figsize=(13, 9))
plt.scatter(data_selected['Humidity'], data_selected['Temperature (C)'])
plt.xlabel('Humidity')
plt.ylabel('Temperature')
plt.title('Humidity vs Temperature')
plt.show()

# %%
# Dữ liệu quá dày đặt, ta tiến hành cắt bớt dữ liệu để phân tích
# Thực hiện lấy 600 điểm dữ liệu của `data_selected`
# YOUR CODE HERE
data_selected = data_selected.head(600)


data_selected.shape
# Out:
# (600, 2)

# %%
data_selected.columns=['Hum','Tmp']

# %%
# Sử dụng biểu đồ để phân tích trên 600 điểm dữ liệu đã cắt
plt.figure(figsize=(13, 9))
plt.scatter(data_selected["Hum"], data_selected["Tmp"])
plt.xlabel('Humidity')
plt.ylabel('Temperature')
plt.title('Humidity vs Temperature')
plt.show()

# %% [markdown]
# Ta có thể thấy rằng giữa `Humidity` và `Temperature` có quan hệ `tuyến tính` với nhau.

# %% [markdown]
# ## 2. Sử dụng Linear Regression để tìm ra quan hệ giữa 2 trường dữ liệu
# Tiếp theo đây, chúng ta sẽ thực hiện mô hình Linear Reggression đã cài đặt tại `Phần 1` để thực hiện nội dung này.

# %%
tmp
# Out:
# 0       9.472222
# 1       9.355556
# 2       9.377778
# 3       8.288889
# 4       8.755556
#          ...
# 595    10.227778
# 596     9.227778
# 597     7.827778
# 598     6.677778
# 599     6.122222
# Name: Tmp, Length: 600, dtype: float64

# %%
# Lấy ra trường `Humidity` và `Temperature` để tiến hành huấn luyện
# YOUR CODE HERE
hum = data_selected['Hum']
tmp = data_selected['Tmp']  
#raise NotImplementedError()
opt = tf.keras.optimizers.SGD(learning_rate=0.1) # Stochastic Gradient Descent

# Tìm hiểu về loss function. Loss function được sử dụng trong Linear Regression là gì?
# YOUR CODE HERE
loss = 'mse'

LinearRegression.compile(optimizer=opt, loss=loss)
hist = LinearRegression.fit(hum, tmp, epochs=35
)
# Out:
# Epoch 1/35
# 19/19 [==============================] - 0s 2ms/step - loss: 16.9397
# Epoch 2/35
# 19/19 [==============================] - 0s 2ms/step - loss: 15.9511
# Epoch 3/35
# 19/19 [==============================] - 0s 2ms/step - loss: 14.8470
# Epoch 4/35
# 19/19 [==============================] - 0s 2ms/step - loss: 14.0646
# Epoch 5/35
# 19/19 [==============================] - 0s 2ms/step - loss: 13.3210
# Epoch 6/35
# 19/19 [==============================] - 0s 2ms/step - loss: 12.7290
# Epoch 7/35
# 19/19 [==============================] - 0s 2ms/step - loss: 12.1741
# Epoch 8/35
# 19/19 [==============================] - 0s 2ms/step - loss: 11.6990
# Epoch 9/35
# 19/19 [==============================] - 0s 2ms/step - loss: 11.2622
# Epoch 10/35
# 19/19 [==============================] - 0s 2ms/step - loss: 10.9194
# Epoch 11/35
# 19/19 [==============================] - 0s 2ms/step - loss: 10.5792
# Epoch 12/35
# 19/19 [==============================] - 0s 2ms/step - loss: 10.2712
# Epoch 13/35
# 19/19 [==============================] - 0s 2ms/step - loss: 10.1050
# Epoch 14/35
# 19/19 [==============================] - 0s 2ms/step - loss: 9.8533
# Epoch 15/35
# 19/19 [==============================] - 0s 2ms/step - loss: 9.6499
# Epoch 16/35
# 19/19 [==============================] - 0s 2ms/step - loss: 9.4903
# Epoch 17/35
# 19/19 [==============================] - 0s 2ms/step - loss: 9.4221
# Epoch 18/35
# 19/19 [==============================] - 0s 2ms/step - loss: 9.3772
# Epoch 19/35
# 19/19 [==============================] - 0s 1ms/step - loss: 9.1784
# Epoch 20/35
# 19/19 [==============================] - 0s 2ms/step - loss: 9.1025
# Epoch 21/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.9763
# Epoch 22/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.8964
# Epoch 23/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.8853
# Epoch 24/35
# 19/19 [==============================] - 0s 1ms/step - loss: 8.7828
# Epoch 25/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.8561
# Epoch 26/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.7297
# Epoch 27/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.6760
# Epoch 28/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.6517
# Epoch 29/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.6526
# Epoch 30/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.6772
# Epoch 31/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.6344
# Epoch 32/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.5743
# Epoch 33/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.5971
# Epoch 34/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.5401
# Epoch 35/35
# 19/19 [==============================] - 0s 2ms/step - loss: 8.5133

# %%
# Hiển thị loss theo số epoch
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 3. Kiểm tra, trực quan hóa kết quả dựa trên biểu đồ và các giá trị độ chính xác

# %%
tmp_predict = pretrain_LinearRegression.predict(np.array([np.min(hum), np.max(hum)]).reshape(-1,1))
tmp_predict
# Out:
# 1/1 [==============================] - 0s 44ms/step
# array([[13.713361],
#        [12.161296]], dtype=float32)

# %%
LinearRegression.save('linear_regression_model.h5')

pretrain_LinearRegression = load_model('linear_regression_model.h5')

# %%
# Thể hiện kết quả thu được dựa trên mô hình Linear Regession

plt.figure(figsize=(13, 9))
plt.scatter(hum,tmp)

# Dự đoán các giá trị temperature dựa trên mô hình Linear Regession đã huấn luyện
# YOUR CODE HERE
hum_get = np.array([np.min(hum), np.max(hum)]).reshape(-1,1)
tmp_predict = pretrain_LinearRegression.predict(hum)
# raise NotImplementedError()

plt.plot(hum,tmp_predict ,"r-")
plt.xlabel('Humidity')
plt.ylabel('Temperature')
plt.title('Result relationship between Humidity and Temperature')
plt.legend()
plt.show()
# Out:
# 19/19 [==============================] - 0s 1ms/step
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Tìm hiểu về các độ lỗi `MSE`, `MAE`, `MAPE` và cho biết ý nghĩa của chúng là gì và chúng thể hiện điều gì?

# %%
mse = tf.keras.losses.MeanSquaredError()
mse(tmp, tmp_predict).numpy()
# Out:
# 29.321358

# %%
# YOUR CODE HERE
mae =  tf.keras.losses.MeanAbsoluteError()
mae(tmp,tmp_predict).numpy()
# Out:
# 4.3718

# %%
# YOUR CODE HERE
mape = tf.keras.losses.MeanAbsolutePercentageError()
mape(tmp,tmp_predict).numpy
# Out:
# <bound method _EagerTensorBase.numpy of <tf.Tensor: shape=(), dtype=float32, numpy=36.764423>>

# %% [markdown]
# HẾT RỒI, CHÚC MỪNG BẠN ĐÃ HOÀN THÀNH.
